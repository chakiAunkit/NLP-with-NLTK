# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json
import sentiment_mod as s


#consumer key, consumer secret, access token, access secret.
ckey="cN6D41zgtPTXWWkIdqhD1VYDL"
csecret="Wufz22q85GRdJlOONyOxJUJWpnGBDDk8OH4lmD8erV2fc8SvC6"
atoken="3150515735-RTevBT1ZeiObx12gFVlIKphcWB0z3bTkHGxD7j0"
asecret="4TTpUmho9KjaC8OnIa67W07aAmoP7mpLkxQ1rzQTMipxH"

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)

        tweet = all_data["text"]
        sentiment_value, confidence = s.sentiment(tweet)
        print(tweet, sentiment_value, confidence)
        
        if(confidence*100 >= 80):
            output = open('twitter-out.txt', 'a')
            output.write(sentiment_value)
            output.write('\n')
            output.close()

        return True

    def on_error(self, status):
        print (status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["Modi"])
# Out:
# @thiruja TN BJP guys have been helping poor using modis kitchen . What did  you #poralees do ? other than comfortab… https://t.co/MPGLxbfjpi neg 1.0
# @RituRathaur @ChaudhrGurnam @narendramodi @NitishKumar Modi Ji can't go to every village, Nitishkumar must do somet… https://t.co/3a1xayrw7v neg 1.0
# RT @DKforIND: यशवंत सिन्हा ने मोदी को बताया तुगलक, कहा- उसने भी हजारों KM चलवाकर लोगों को मार डाला था @LambaAlka @srinivasiyc
# https://t.co… neg 1.0
# RT @MaheshJinna99: 10 "Ganneru pappu" Moments for you @Akshay_Adurinti .. neg 1.0
# RT @VinayDokania: The architects of the Grand fall of India from A superpower during the Dr Manmohan Singh era to a failure in Modi regime.… neg 1.0
# @advsapnakaushik @Rofl_Swara Digital India aeroplane per chal rahe hain Modi ji Ka Sapna pura ho Gaya Hawai chappal… https://t.co/h0ZA6wp1Rp neg 1.0
# RT @SaralPatel: I remember in an interview with Ravish Kumar before 2019 Lok-Sabha election, @RahulGandhi had said: "I learn from everyone… neg 1.0
# ...
